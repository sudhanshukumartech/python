# %%
bin(12)
# Out:
# '0b1100'

# %%
int("1100" , base = 2)
# Out:
# 12

# %%
#AND operator

# %%
32 & 13
# Out:
# 0

# %%
bin(32)
# Out:
# '0b100000'

# %%
bin(13)
# Out:
# '0b1101'

# %%
5 & 23
# Out:
# 5

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(23)
# Out:
# '0b10111'

# %%
int("00101" ,base = 2)
# Out:
# 5

# %%
-3 & 5
# Out:
# 5

# %%
bin(-3)
# Out:
# '-0b11'

# %%
bin(5)
# Out:
# '0b101'

# %%
int("001" , base = 2)
# Out:
# 1

# %%
int("101" , base = 2)
# Out:
# 5

# %%
-12 & 16
# Out:
# 16

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(16)
# Out:
# '0b10000'

# %%
int("10000",base = 2)
# Out:
# 16

# %%
#OR operator

# %%
12 | 23
# Out:
# 31

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(23)
# Out:
# '0b10111'

# %%
int("11111",base = 2 )
# Out:
# 31

# %%
-14 | 23
# Out:
# -9

# %%
bin(14)
# Out:
# '0b1110'

# %%
bin(23)
# Out:
# '0b10111'

# %%
int("1001",base = 2 )
# Out:
# 9

# %%
#XOR operator

# %%
2^3
# Out:
# 1

# %%
2^4
# Out:
# 6

# %%
bin(2)
# Out:
# '0b10'

# %%
bin(4)
# Out:
# '0b100'

# %%
int("110",base = 2)
# Out:
# 6

# %%
-4 ^ 12
# Out:
# -16

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(12)
# Out:
# '0b1100'

# %%
int("10000",base = 2 )
# Out:
# 16

# %%
#NOT operator

# %%
~21
# Out:
# -22

# %%
~4
# Out:
# -5

# %%
bin(4)
# Out:
# '0b100'

# %%
int("101",base = 2 )
# Out:
# 5

# %%
~-13
# Out:
# 12

# %%
bin(13)
# Out:
# '0b1101'

# %%
int("1100",base = 2 )
# Out:
# 12

# %%
2<< 2
# Out:
# 8

# %%
5<<3
# Out:
# 40

# %%
6<<5
# Out:
# 192

# %%
6>>4
# Out:
# 0

# %%
6>>19
# Out:
# 0

# %%
54634566>>4
# Out:
# 3414660
